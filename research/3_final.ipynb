# %%
import pandas as pd
import requests
import folium
import polyline
import time
from geopy.distance import geodesic

# %%
# ======= CONFIGURATION =======
API_KEY = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM' # Replace with your actual API key
# FILE_PATH = 'data/Gps-Collection.csv'  # Path to your Excel file
FILE_PATH = 'data/Workbook.csv'  # Path to your Excel file
ACCURACY_THRESHOLD = 50 # Max acceptable GPS accuracy (in meters)
MIN_MOVE_DISTANCE_M = 15  # Minimum movement to keep consecutive point
MAX_SNAP_DISTANCE_M = 5  # Max snap-to-road distance allowed

# %%
df = pd.read_csv(FILE_PATH)
df.columns = df.columns.str.strip()
df['DateTime'] = pd.to_datetime(df['DateTime'], format='%d/%m/%Y %I:%M:%S %p')
df = df[df['Accuracy'] <= ACCURACY_THRESHOLD]
df = df[df['Provider'] == 'gps'] 
df = df.sort_values('TimeStamp')

# %%
from geopy.distance import geodesic
import pandas as pd

def remove_concentrated_points(df, lat_col='Latitude', lon_col='Longitude', distance_threshold_m=40):
    """
    Removes spatially concentrated points from a DataFrame based on a minimum geodesic distance threshold.
    
    Parameters:
        df (pd.DataFrame): Input DataFrame containing GPS points.
        lat_col (str): Name of the latitude column.
        lon_col (str): Name of the longitude column.
        distance_threshold_m (float): Minimum distance in meters between retained points.
    
    Returns:
        pd.DataFrame: Filtered DataFrame with spaced-out points.
    """
    cleaned_rows = []
    last_point = None

    for _, row in df.iterrows():
        current_point = (row[lat_col], row[lon_col])
        if last_point is None:
            cleaned_rows.append(row)
            last_point = current_point
        else:
            distance = geodesic(last_point, current_point).meters
            if distance >= distance_threshold_m:
                cleaned_rows.append(row)
                last_point = current_point

    return pd.DataFrame(cleaned_rows)

cleaned_df = remove_concentrated_points(df)
cleaned_df.shape
# Out:
# (378, 13)

# %%
raw_points = list(zip(cleaned_df['Latitude'], cleaned_df['Longitude']))
print(f"Loaded {len(raw_points)} raw points (accuracy ≤ {ACCURACY_THRESHOLD})")
# Out:
# Loaded 378 raw points (accuracy ≤ 50)

# %%
# Step 3: Snap to nearest road, reject if too far from road
def snap_to_nearest_road_filtered(points, max_snap_distance_m=15):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=false&key={API_KEY}"
        r = requests.get(url)
        data = r.json()

        if 'snappedPoints' in data:
            for p in data['snappedPoints']:
                if 'originalIndex' not in p:
                    continue
                idx = p['originalIndex']
                original = batch[idx]
                snapped_point = (p['location']['latitude'], p['location']['longitude'])

                distance = geodesic(original, snapped_point).meters
                if distance <= max_snap_distance_m:
                    snapped.append(snapped_point)
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

# %%
def get_hybrid_road_path(points, max_direct_distance_m=50):
    total_km = 0
    route_coords = []

    for i in range(len(points) - 1):
        origin = points[i]
        destination = points[i + 1]
        distance_m = geodesic(origin, destination).meters

        if distance_m <= max_direct_distance_m:
            total_km += distance_m / 1000
            if not route_coords or route_coords[-1] != origin:
                route_coords.append(origin)
            route_coords.append(destination)
        else:
            # 🌐 Use Google Directions API for road-based path
            url = (
                f"https://maps.googleapis.com/maps/api/directions/json?"
                f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
                f"&key={API_KEY}"
            )

            r = requests.get(url).json()
            if r.get("status") == "OK":
                try:
                    poly = r["routes"][0]["overview_polyline"]["points"]
                    route_coords.extend(polyline.decode(poly))
                    for leg in r["routes"][0]["legs"]:
                        total_km += leg["distance"]["value"] / 1000
                except Exception as e:
                    print(f"⚠️ Polyline decode error at segment {i}: {e}")
            else:
                print(f"❌ Directions error [{i}]:", r.get("status"), r.get("error_message"))
                # fallback to geodesic
                total_km += distance_m / 1000
                route_coords.append(origin)
                route_coords.append(destination)

            time.sleep(0.1)  # API rate limit safety

    return total_km, route_coords

# %%
snapped_path =snap_to_nearest_road_filtered(raw_points)

# %%
total_km, route_coords = get_hybrid_road_path(snapped_path)
total_km
# Out:
# 15.912960246614444

# %%
def visualize_all_locations(df):
    """
    Visualize all locations from a CSV file on a folium map.
    :param csv_file_path: Path to the CSV file containing location data
    :return: folium.Map object
    """
    # Load the CSV data into a DataFrame
    # try:
    #     df = df
    # except Exception as e:
    #     print(f"Error loading CSV file {csv_file_path}: {e}")
    #     return None
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            # popup=f"CODE: {row['CODE']}<br>LOCATION: {row['LOCATION']}<br>ADDRESS: {row['ADDRESS']}<br>BRAND: {row['BRAND']}",
            popup=f"Accuracy: {row['Accuracy']}<br>Latitude: {row['Latitude']}<br>Longitude: {row['Longitude']}<br>DeviceTime: {row['DeviceTime']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">All Locations Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

"""View snapped path on map"""
def visualize_snapped_path(snapped_path):
    """
    Visualize the snapped path on a folium map.
    :param snapped_path: List of snapped points
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [sum(p[0] for p in snapped_path) / len(snapped_path),
                      sum(p[1] for p in snapped_path) / len(snapped_path)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each snapped point
    for point in snapped_path:
        folium.Marker(
            location=point,
            popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Snapped Path Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

"""Visualize route_coords on map"""
def visualize_route_coords(route_coords):
    """
    Visualize the route coordinates on a folium map.
    :param route_coords: List of route coordinates
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes 
        map_center = [sum(p[0] for p in route_coords) / len(route_coords),
                      sum(p[1] for p in route_coords) / len(route_coords)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each route coordinate
    for point in route_coords:
            folium.Marker(
                location=point,
                popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
                icon=folium.Icon(color='red', icon='info-sign')
            ).add_to(m)
            
    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Route Coordinates Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

# %%
visualize_all_locations(cleaned_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c8f4b5b30c916c50d1b616694a22fcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;All Locations Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c8f4b5b30c916c50d1b616694a22fcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c8f4b5b30c916c50d1b616694a22fcb = L.map(
#                 &quot;map_8c8f4b5b30c916c50d1b616694a22fcb&quot;,
#                 {
#                     center: [6.876833333333334, 80.03048486772487],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_714bb2dcf9cfba718b9c03e33e0a9893 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8c8f4b5b30c916c50d1b616694a22fcb);
#
#
#             var marker_9b4cc584b6c00c8a27abdd1e1b361ea6 = L.marker(
#                 [6.89274, 80.03597],
#                 {}
#             ).addTo(map_8c8f4b5b30c916c50d1b616694a22fcb);
#
#
#             var icon_f82b87070f14290a286bd908bf3580fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b4cc584b6c00c8a27abdd1e1b361ea6.setIcon(icon_f82b87070f14290a286bd908bf3580fd);
#
#
#         var popup_ce883b3c1c3ae0bea77a49e3d4425136 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ca877f5f0008c99e938ac9947100799 = $(`&lt;div id=&quot;html_1ca877f5f0008c99e938ac9947100799&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 1.6&lt;br&gt;Latitude: 6.89274&lt;br&gt;Longitude: 80.03597&lt;br&gt;DeviceTime: 15/05/2025 9:29:06 AM&lt;/div&gt;`)[0];
#                 popup_ce883b3c1c3ae0bea77a49e3d4425136.setContent(html_1ca877f5f0008c99e938ac9947100799);
#
#
#
#         marker_9b4cc584b6c00c8a27abdd1e1b361ea6.bindPopup(popup_ce883b3c1c3ae0bea77a49e3d4425136)
#         ;
#
#
#
#
#             var marker_f4f47aa6ca11f888b7f676867aa3fc0a = L.marker(
#                 [6.89312, 80.03592],
#                 {}
#             ).addTo(map_8c8f4b5b30c916c50d1b616694a22fcb);
#
#
#             var icon_99ee19f71acbb92d2076a33464a40f19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f4f47aa6ca11f888b7f676867aa3fc0a.setIcon(icon_99ee19f71acbb92d2076a33464a40f19);
#
#
#         var popup_ebed34aa0618ba3ef65a3b774e849a14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_176cee75146093b464cd1f2803b3c5a9 = $(`&lt;div id=&quot;html_176cee75146093b464cd1f2803b3c5a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 2.7&lt;br&gt;Latitude: 6.89312&lt;br&gt;Longitude: 80.03592&lt;br&gt;DeviceTime: 15/05/2025 9:33:35 AM&lt;/div&gt;`)[0];
#                 popup_ebed34aa0618ba3ef65a3b774e849a14.setContent(html_176cee75146093b464cd1f2803b3c5a9);
#
#
#
#         marker_f4f47aa6ca11f888b7f676867aa3fc0a.bindPopup(popup_ebed34aa0618ba3ef65a3b774e849a14)
#         ;
#
#
#
#
#             var marker_f023ed34c56dc98caf31f2597198a1ee = L.marker(
#                 [6.89345, 80.03607],
#                 {}
#             ).addTo(map_8c8f4b5b30c916c50d1b616694a22fcb);
#
#
#             var icon_1d8bd1578d03e0d3b5aee62c16c2f4e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f023ed34c56dc98caf31f2597198a1ee.setIcon(icon_1d8bd1578d03e0d3b5aee62c16c2f4e1);
#
#
#         var popup_2c11e472db02ba59b33e5bfd86493cda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a7d8fececd7e1e096508734f0ae02c1 = $(`&lt;div id=&quot;html_5a7d8fececd7e1e096508734f0ae02c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 1.8&lt;br&gt;Latitude: 6.89345&lt;br&gt;Longitude: 80.03607&lt;br&gt;DeviceTime: 15/05/2025 9:33:42 AM&lt;/div&gt;`)[0];
#                 popup_2c11e472db02ba59b33e5bfd86493cda.setContent(html_5a7d8fececd7e1e096508734f0ae02c1);
#
#
#
#         marker_f023ed34c56dc98caf31f2597198a1ee.bindPopup(popup_2c11e472db02ba59b33e5bfd86493cda

# %%
visualize_snapped_path(snapped_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f28bdcb535969e006b2821953c30ce17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f28bdcb535969e006b2821953c30ce17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f28bdcb535969e006b2821953c30ce17 = L.map(
#                 &quot;map_f28bdcb535969e006b2821953c30ce17&quot;,
#                 {
#                     center: [6.876179830044701, 80.03034897839039],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e18305e90ca8682a5685a96041d06c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f28bdcb535969e006b2821953c30ce17);
#
#
#             var marker_e77e1427a08f1cb3521cc24d63feda60 = L.marker(
#                 [6.893187499999999, 80.03597529999999],
#                 {}
#             ).addTo(map_f28bdcb535969e006b2821953c30ce17);
#
#
#             var icon_f1ca8dad57b6e1a869ec41612611615e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e77e1427a08f1cb3521cc24d63feda60.setIcon(icon_f1ca8dad57b6e1a869ec41612611615e);
#
#
#         var popup_99a325d61f1044ddd4a91ea951d268d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d24b14497ee67b6eb70e9196d67180 = $(`&lt;div id=&quot;html_36d24b14497ee67b6eb70e9196d67180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893187499999999&lt;br&gt;Longitude: 80.03597529999999&lt;/div&gt;`)[0];
#                 popup_99a325d61f1044ddd4a91ea951d268d7.setContent(html_36d24b14497ee67b6eb70e9196d67180);
#
#
#
#         marker_e77e1427a08f1cb3521cc24d63feda60.bindPopup(popup_99a325d61f1044ddd4a91ea951d268d7)
#         ;
#
#
#
#
#             var marker_7fe645de3ae7960c93dfbf9b26276fb3 = L.marker(
#                 [6.893398978845667, 80.03605296559903],
#                 {}
#             ).addTo(map_f28bdcb535969e006b2821953c30ce17);
#
#
#             var icon_117e4df4b71aaad197624323af776303 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fe645de3ae7960c93dfbf9b26276fb3.setIcon(icon_117e4df4b71aaad197624323af776303);
#
#
#         var popup_5790549055e86f73927ff29b98ef03d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e05c1964aa07baabbf1d7eabb77b6af2 = $(`&lt;div id=&quot;html_e05c1964aa07baabbf1d7eabb77b6af2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893398978845667&lt;br&gt;Longitude: 80.03605296559903&lt;/div&gt;`)[0];
#                 popup_5790549055e86f73927ff29b98ef03d4.setContent(html_e05c1964aa07baabbf1d7eabb77b6af2);
#
#
#
#         marker_7fe645de3ae7960c93dfbf9b26276fb3.bindPopup(popup_5790549055e86f73927ff29b98ef03d4)
#         ;
#
#
#
#
#             var marker_d17848f700269e5f75d4ff9759f51071 = L.marker(
#                 [6.8932720681973985, 80.03643640955518],
#                 {}
#             ).addTo(map_f28bdcb535969e006b2821953c30ce17);
#
#
#             var icon_400cc0269c5cbcc163ba8cbf9715c1ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d17848f700269e5f75d4ff9759f51071.setIcon(icon_400cc0269c5cbcc163ba8cbf9715c1ec);
#
#
#         var popup_17224ca236c263b49efa4c3813493564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0b5bd4740a0d39a1efe2383486485c5 = $(`&lt;div id=&quot;html_f0b5bd4740a0d39a1efe2383486485c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.8932720681973985&lt;br&gt;Longitude: 80.03643640955518&lt;/div&gt;`)[0];
#                 popup_17224ca236c263b49efa4c3813493564.setContent(html_f0b5bd4740a0d39a1efe2383486485c5);
#
#
#
#         marker_d17848f700269e5f75d4ff9759f51071.bindPopup(popup_17224ca236c263b49efa4c3813493564)
#         ;
#
#
#
#
#             var marker_deef7a4f7db2a333e1b043548

# %%
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8851bdc02c270d98dd98e38c8ce366d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8851bdc02c270d98dd98e38c8ce366d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8851bdc02c270d98dd98e38c8ce366d7 = L.map(
#                 &quot;map_8851bdc02c270d98dd98e38c8ce366d7&quot;,
#                 {
#                     center: [6.87708220794745, 80.03072561515177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b275397be8644ec8fcbbf9fa41742495 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8851bdc02c270d98dd98e38c8ce366d7);
#
#
#             var marker_5012e7ef1576822ee471dfa0e3f1aed0 = L.marker(
#                 [6.893187499999999, 80.03597529999999],
#                 {}
#             ).addTo(map_8851bdc02c270d98dd98e38c8ce366d7);
#
#
#             var icon_ef90bce50b2f24c94e09ad812f890e4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5012e7ef1576822ee471dfa0e3f1aed0.setIcon(icon_ef90bce50b2f24c94e09ad812f890e4c);
#
#
#         var popup_e21fac3d77b8227f066ea84bbc82f3b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11221a9eb77cf6411af6713f2b5abb58 = $(`&lt;div id=&quot;html_11221a9eb77cf6411af6713f2b5abb58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893187499999999&lt;br&gt;Longitude: 80.03597529999999&lt;/div&gt;`)[0];
#                 popup_e21fac3d77b8227f066ea84bbc82f3b9.setContent(html_11221a9eb77cf6411af6713f2b5abb58);
#
#
#
#         marker_5012e7ef1576822ee471dfa0e3f1aed0.bindPopup(popup_e21fac3d77b8227f066ea84bbc82f3b9)
#         ;
#
#
#
#
#             var marker_e84b93e201f654b823589f8a4363ea73 = L.marker(
#                 [6.893398978845667, 80.03605296559903],
#                 {}
#             ).addTo(map_8851bdc02c270d98dd98e38c8ce366d7);
#
#
#             var icon_792fbee727d6d0f03422aecab0eb3474 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e84b93e201f654b823589f8a4363ea73.setIcon(icon_792fbee727d6d0f03422aecab0eb3474);
#
#
#         var popup_80ba22cb13e0b2bd1fb6cc5e7f0b4337 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e48da31b45b1628ad9042a3bccfee339 = $(`&lt;div id=&quot;html_e48da31b45b1628ad9042a3bccfee339&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893398978845667&lt;br&gt;Longitude: 80.03605296559903&lt;/div&gt;`)[0];
#                 popup_80ba22cb13e0b2bd1fb6cc5e7f0b4337.setContent(html_e48da31b45b1628ad9042a3bccfee339);
#
#
#
#         marker_e84b93e201f654b823589f8a4363ea73.bindPopup(popup_80ba22cb13e0b2bd1fb6cc5e7f0b4337)
#         ;
#
#
#
#
#             var marker_0acc03728abe2e896ccdb89164842c72 = L.marker(
#                 [6.8932720681973985, 80.03643640955518],
#                 {}
#             ).addTo(map_8851bdc02c270d98dd98e38c8ce366d7);
#
#
#             var icon_074eceb07c92e301cdb5093b133351dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0acc03728abe2e896ccdb89164842c72.setIcon(icon_074eceb07c92e301cdb5093b133351dc);
#
#
#         var popup_eb2a85bef13d6088655a5bb80b887152 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_615750e24155cf9774baf16a2d8786ec = $(`&lt;div id=&quot;html_615750e24155cf9774baf16a2d8786ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.8932720681973985&lt;br&gt;Longitude: 80.03643640955518&lt;/div&gt;`)[0];
#                 popup_eb2a85bef13d6088655a5bb80b887152.setContent(html_615750e24155cf9774baf16a2d8786ec);
#
#
#
#         marker_0acc03728abe2e896ccdb89164842c72.bindPopup(popup_eb2a85bef13d6088655a5bb80b887152)
#         ;
#
#
#
#
#             var marker_80a41e46e637b7d81a3464cab8f
