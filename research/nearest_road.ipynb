# %%
import pandas as pd
import requests
import folium
import polyline
import time
from geopy.distance import geodesic

# %%
# ======= CONFIGURATION =======
API_KEY = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM' # Replace with your actual API key
FILE_PATH = 'data/Gps-Collection.csv'  # Path to your Excel file
ACCURACY_THRESHOLD = 25 # Max acceptable GPS accuracy (in meters)
MIN_MOVE_DISTANCE_M = 15  # Minimum movement to keep consecutive point
MAX_SNAP_DISTANCE_M = 5  # Max snap-to-road distance allowed

# %%
# Step 1: Load and filter by GPS accuracy
df = pd.read_csv(FILE_PATH)
df.columns = df.columns.str.strip()
df_filtered = df[df['Accuracy'] <= ACCURACY_THRESHOLD]
raw_points = list(zip(df_filtered['Latitude'], df_filtered['Longitude']))
print(f"Loaded {len(raw_points)} raw points (accuracy ≤ {ACCURACY_THRESHOLD})")
# Out:
# Loaded 499 raw points (accuracy ≤ 25)

# %%
def visualize_all_locations(df):
    """
    Visualize all locations from a CSV file on a folium map.
    :param csv_file_path: Path to the CSV file containing location data
    :return: folium.Map object
    """
    # Load the CSV data into a DataFrame
    # try:
    #     df = df
    # except Exception as e:
    #     print(f"Error loading CSV file {csv_file_path}: {e}")
    #     return None
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            # popup=f"CODE: {row['CODE']}<br>LOCATION: {row['LOCATION']}<br>ADDRESS: {row['ADDRESS']}<br>BRAND: {row['BRAND']}",
            popup=f"Accuracy: {row['Accuracy']}<br>Latitude: {row['Latitude']}<br>Longitude: {row['Longitude']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">All Locations Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

# %%
visualize_all_locations(df_filtered)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9da4013162ed889f73186aef00c7545 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;All Locations Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9da4013162ed889f73186aef00c7545&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9da4013162ed889f73186aef00c7545 = L.map(
#                 &quot;map_d9da4013162ed889f73186aef00c7545&quot;,
#                 {
#                     center: [6.280830641282565, 80.05252619238479],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a1f37399f576c7ec1505c0c618be4d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a1f37399f576c7ec1505c0c618be4d6.addTo(map_d9da4013162ed889f73186aef00c7545);
#
#
#             var marker_8361177554c7367fc86a0f5428c35f00 = L.marker(
#                 [6.13852, 80.10066],
#                 {
# }
#             ).addTo(map_d9da4013162ed889f73186aef00c7545);
#
#
#             var icon_835b9bb07b980f977e0f3d940c6a4f67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8361177554c7367fc86a0f5428c35f00.setIcon(icon_835b9bb07b980f977e0f3d940c6a4f67);
#
#
#         var popup_8c824244298b3927c83d1f94acb7501f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94229614b5b60983ed239e13731b92ed = $(`&lt;div id=&quot;html_94229614b5b60983ed239e13731b92ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 20.0&lt;br&gt;Latitude: 6.13852&lt;br&gt;Longitude: 80.10066&lt;/div&gt;`)[0];
#                 popup_8c824244298b3927c83d1f94acb7501f.setContent(html_94229614b5b60983ed239e13731b92ed);
#
#
#
#         marker_8361177554c7367fc86a0f5428c35f00.bindPopup(popup_8c824244298b3927c83d1f94acb7501f)
#         ;
#
#
#
#
#             var marker_0bcd6d988b044f641f25f419d374c49b = L.marker(
#                 [6.13848, 80.10074],
#                 {
# }
#             ).addTo(map_d9da4013162ed889f73186aef00c7545);
#
#
#             var icon_67140cc5a5f50ad2dd554e3c9acfedb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0bcd6d988b044f641f25f419d374c49b.setIcon(icon_67140cc5a5f50ad2dd554e3c9acfedb0);
#
#
#         var popup_09405de79d0c37765904074ca0a1c054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dc650fcc63e20bf617d54d3e0531af0 = $(`&lt;div id=&quot;html_8dc650fcc63e20bf617d54d3e0531af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 13.0&lt;br&gt;Latitude: 6.13848&lt;br&gt;Longitude: 80.10074&lt;/div&gt;`)[0];
#                 popup_09405de79d0c37765904074ca0a1c054.setContent(html_8dc650fcc63e20bf617d54d3e0531af0);
#
#
#
#         marker_0bcd6d988b044f641f25f419d374c49b.bindPopup(popup_09405de79d0c37765904074ca0a1c054)
#         ;
#
#
#
#
#             var marker_053667dd46596b3d1f608dcc5a4f9e2f = L.marker(
#                 [6.13856, 80.10079],
#                 {
# }
#             ).addTo(map_d9da4013162ed889f73186aef00c7545);
#
#
#             var icon_15aed095f0366a887461c9999d0ce0b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_053667dd46596b3d1f608dcc5a4f9e2f.setIcon(icon_15aed095f0366a887461c9999d0ce0b2);
#
#
#         var popup_eb4ed907b92de48589ca414edffe8683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cadf01c6dd1cdb1c2107fa24878845d1 = $(`&lt;div id=&quot;html_cadf01c6dd1cdb1c2107fa24878845d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 3.5&lt;br&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.10079&lt;/div&gt;`)[0];
#                 popup_eb4ed907b92de48589ca414edffe8683.setContent(html_cadf01c6dd1cdb1c2107fa24878845d1);
#
#
#
#         marker_053667dd46596b3d1f608dcc5a4f9e2f.bindPopup(popup_eb4ed907b92de48589ca414edffe8683)
#         ;
#
#
#
#
#             var marker_3cfa68182172eb20a90f4cfd6192b857 = L.marker(

# %%
# Step 3: Snap to nearest road, reject if too far from road
def snap_to_nearest_road_filtered(points, max_snap_distance_m=15):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=false&key={API_KEY}"
        r = requests.get(url)
        data = r.json()

        if 'snappedPoints' in data:
            for p in data['snappedPoints']:
                if 'originalIndex' not in p:
                    continue
                idx = p['originalIndex']
                original = batch[idx]
                snapped_point = (p['location']['latitude'], p['location']['longitude'])

                distance = geodesic(original, snapped_point).meters
                if distance <= max_snap_distance_m:
                    snapped.append(snapped_point)
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

# %%
snapped_path =snap_to_nearest_road_filtered(raw_points)

# %%
"""View snapped path on map"""
def visualize_snapped_path(snapped_path):
    """
    Visualize the snapped path on a folium map.
    :param snapped_path: List of snapped points
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [sum(p[0] for p in snapped_path) / len(snapped_path),
                      sum(p[1] for p in snapped_path) / len(snapped_path)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each snapped point
    for point in snapped_path:
        folium.Marker(
            location=point,
            popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Snapped Path Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_snapped_path(snapped_path[:-20])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a3c8bdc9b86a5f796c8d14216e5f58d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a3c8bdc9b86a5f796c8d14216e5f58d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a3c8bdc9b86a5f796c8d14216e5f58d = L.map(
#                 &quot;map_9a3c8bdc9b86a5f796c8d14216e5f58d&quot;,
#                 {
#                     center: [6.139083597848773, 80.10048508703004],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84ecda5f047e66b9a2023cce2b86c390 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84ecda5f047e66b9a2023cce2b86c390.addTo(map_9a3c8bdc9b86a5f796c8d14216e5f58d);
#
#
#             var marker_0515eb338169b1ae24b2ef61785f8183 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_9a3c8bdc9b86a5f796c8d14216e5f58d);
#
#
#             var icon_f0014d3c9aacb2950e9bcd5b508b5a2b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0515eb338169b1ae24b2ef61785f8183.setIcon(icon_f0014d3c9aacb2950e9bcd5b508b5a2b);
#
#
#         var popup_0b6e664d0c55b864e5d0ff22f740f221 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e9d500e5802bee14585e40e897e0a46 = $(`&lt;div id=&quot;html_8e9d500e5802bee14585e40e897e0a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_0b6e664d0c55b864e5d0ff22f740f221.setContent(html_8e9d500e5802bee14585e40e897e0a46);
#
#
#
#         marker_0515eb338169b1ae24b2ef61785f8183.bindPopup(popup_0b6e664d0c55b864e5d0ff22f740f221)
#         ;
#
#
#
#
#             var marker_ddffd806c77c8e53d4a43a581fe58269 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_9a3c8bdc9b86a5f796c8d14216e5f58d);
#
#
#             var icon_6bd206cb2d78f24ef326821e2d0e10bb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_ddffd806c77c8e53d4a43a581fe58269.setIcon(icon_6bd206cb2d78f24ef326821e2d0e10bb);
#
#
#         var popup_b049f66d42df457f8269ff1837359407 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_418e6398c1c8d48057b29fcaaa94c22d = $(`&lt;div id=&quot;html_418e6398c1c8d48057b29fcaaa94c22d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_b049f66d42df457f8269ff1837359407.setContent(html_418e6398c1c8d48057b29fcaaa94c22d);
#
#
#
#         marker_ddffd806c77c8e53d4a43a581fe58269.bindPopup(popup_b049f66d42df457f8269ff1837359407)
#         ;
#
#
#
#
#             var marker_523145e99d4cf260f6b14af2f16aa7ee = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_9a3c8bdc9b86a5f796c8d14216e5f58d);
#
#
#             var icon_8cd4ab68cdfdfefb828f2006eddc86be = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_523145e99d4cf260f6b14af2f16aa7ee.setIcon(icon_8cd4ab68cdfdfefb828f2006eddc86be);
#
#
#         var popup_cee8706b8bec7f7ffb044ee4e779a1e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa1f2f325f4c2cf438b4f899325efdba = $(`&lt;div id=&quot;html_fa1f2f325f4c2cf438b4f899325efdba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_cee8706b8bec7f7ffb044ee4e779a1e3.setContent(html_fa1f2f325f4c2cf438b4f899325efdba);
#
#
#
#         marker_523145e99d4cf260f6b14af2f16aa7ee.bindPopup(popup_cee8706b8bec7f7ffb044ee4e779a1e3)
#         ;
#
#
#
#
#             var marker_7b197d295f4ab13a4b2f2cc98ed4679c = L.marker(
#                 [6.138559, 80.1008014],

# %%
# Step 5A: Get total road distance and path (point-by-point)
def get_precise_road_path(points):
    total_km = 0
    route_coords = []

    for i in range(len(points) - 1):
        origin = points[i]
        destination = points[i + 1]

        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&key={API_KEY}"
        )

        r = requests.get(url).json()
        if r["status"] == "OK":
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
            for leg in r["routes"][0]["legs"]:
                total_km += leg["distance"]["value"] / 1000  # meters to km
        else:
            print(f"❗ Segment error [{i}]:", r.get("status"), r.get("error_message"))
        time.sleep(0.1)

    return total_km, route_coords
total_km, route_coords = get_precise_road_path(snapped_path[:-20])

# %%
total_km
# Out:
# 1.5699999999999996

# %%
"""Visualize route_coords on map"""
def visualize_route_coords(route_coords):
    """
    Visualize the route coordinates on a folium map.
    :param route_coords: List of route coordinates
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes 
        map_center = [sum(p[0] for p in route_coords) / len(route_coords),
                      sum(p[1] for p in route_coords) / len(route_coords)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each route coordinate
    for point in route_coords:
            folium.Marker(
                location=point,
                popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
                icon=folium.Icon(color='red', icon='info-sign')
            ).add_to(m)
            
    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Route Coordinates Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_914f755a0fa28f6a5dbca21746086554 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_914f755a0fa28f6a5dbca21746086554&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_914f755a0fa28f6a5dbca21746086554 = L.map(
#                 &quot;map_914f755a0fa28f6a5dbca21746086554&quot;,
#                 {
#                     center: [6.139317187499999, 80.10064099999997],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e51e17fa204318445565d20f77f428d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e51e17fa204318445565d20f77f428d.addTo(map_914f755a0fa28f6a5dbca21746086554);
#
#
#             var marker_75a171398ca4c77c5f4c7037917e5594 = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo(map_914f755a0fa28f6a5dbca21746086554);
#
#
#             var icon_70e6ab68098335ea59b27e7ebc1468b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_75a171398ca4c77c5f4c7037917e5594.setIcon(icon_70e6ab68098335ea59b27e7ebc1468b2);
#
#
#         var popup_1316d08c7bcac31954de1ebb060c5540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17cde144b0e502a54a05b3582be8537e = $(`&lt;div id=&quot;html_17cde144b0e502a54a05b3582be8537e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.1008&lt;/div&gt;`)[0];
#                 popup_1316d08c7bcac31954de1ebb060c5540.setContent(html_17cde144b0e502a54a05b3582be8537e);
#
#
#
#         marker_75a171398ca4c77c5f4c7037917e5594.bindPopup(popup_1316d08c7bcac31954de1ebb060c5540)
#         ;
#
#
#
#
#             var marker_a035c2691f186105744367fbf72143ad = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo(map_914f755a0fa28f6a5dbca21746086554);
#
#
#             var icon_62c072688eb49332f261b952e95d5d97 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a035c2691f186105744367fbf72143ad.setIcon(icon_62c072688eb49332f261b952e95d5d97);
#
#
#         var popup_c36184b5b6a3291075d2c9b84fd41672 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec88f4fe36249e483c011465ddf4721c = $(`&lt;div id=&quot;html_ec88f4fe36249e483c011465ddf4721c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.1008&lt;/div&gt;`)[0];
#                 popup_c36184b5b6a3291075d2c9b84fd41672.setContent(html_ec88f4fe36249e483c011465ddf4721c);
#
#
#
#         marker_a035c2691f186105744367fbf72143ad.bindPopup(popup_c36184b5b6a3291075d2c9b84fd41672)
#         ;
#
#
#
#
#             var marker_455cc9d3525fb33ca4988cdb67cf65d5 = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo(map_914f755a0fa28f6a5dbca21746086554);
#
#
#             var icon_2fd7922babe08a86467ae1810b336aee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_455cc9d3525fb33ca4988cdb67cf65d5.setIcon(icon_2fd7922babe08a86467ae1810b336aee);
#
#
#         var popup_dc21a52160f57166a4c707aafefbf9f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f27cb7fc82e48812ebae09e8fcd01b01 = $(`&lt;div id=&quot;html_f27cb7fc82e48812ebae09e8fcd01b01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.1008&lt;/div&gt;`)[0];
#                 popup_dc21a52160f57166a4c707aafefbf9f6.setContent(html_f27cb7fc82e48812ebae09e8fcd01b01);
#
#
#
#         marker_455cc9d3525fb33ca4988cdb67cf65d5.bindPopup(popup_dc21a52160f57166a4c707aafefbf9f6)
#         ;
#
#
#
#
#             var marker_1240cbb11702cf985cf2aea73aa2a08a = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo

# %%
def snap_to_roads_full_path(points):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=true&key={API_KEY}"
        r = requests.get(url)
        data = r.json()
        if 'snappedPoints' in data:
            snapped.extend([
                (p['location']['latitude'], p['location']['longitude'])
                for p in data['snappedPoints']
            ])
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

snapped_path =snap_to_roads_full_path(raw_points)

# %%
visualize_snapped_path(snapped_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa94a5692a2f33567ddece6b781fb3ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa94a5692a2f33567ddece6b781fb3ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa94a5692a2f33567ddece6b781fb3ad = L.map(
#                 &quot;map_fa94a5692a2f33567ddece6b781fb3ad&quot;,
#                 {
#                     center: [6.311274020023402, 80.04221971152322],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e060aef6d3ddfadb652b521eae9cc083 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e060aef6d3ddfadb652b521eae9cc083.addTo(map_fa94a5692a2f33567ddece6b781fb3ad);
#
#
#             var marker_1d38357bd120b6bc246027ea5916beef = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_fa94a5692a2f33567ddece6b781fb3ad);
#
#
#             var icon_76ae000863a064ab4c6f1cb476e1917d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1d38357bd120b6bc246027ea5916beef.setIcon(icon_76ae000863a064ab4c6f1cb476e1917d);
#
#
#         var popup_f478dfe182bf7031911bcbac58f0929c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a52c23bf32f9cadd8242a3b9557212 = $(`&lt;div id=&quot;html_42a52c23bf32f9cadd8242a3b9557212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_f478dfe182bf7031911bcbac58f0929c.setContent(html_42a52c23bf32f9cadd8242a3b9557212);
#
#
#
#         marker_1d38357bd120b6bc246027ea5916beef.bindPopup(popup_f478dfe182bf7031911bcbac58f0929c)
#         ;
#
#
#
#
#             var marker_66d88ae4cc0d44858f1dc38696267d93 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_fa94a5692a2f33567ddece6b781fb3ad);
#
#
#             var icon_382fec8e36d4ffdbc170392267df4e83 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_66d88ae4cc0d44858f1dc38696267d93.setIcon(icon_382fec8e36d4ffdbc170392267df4e83);
#
#
#         var popup_f75fb5cbf2550f11c1d0aad1bc798de2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ea4f28d23603812f7bf82526308d874 = $(`&lt;div id=&quot;html_4ea4f28d23603812f7bf82526308d874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_f75fb5cbf2550f11c1d0aad1bc798de2.setContent(html_4ea4f28d23603812f7bf82526308d874);
#
#
#
#         marker_66d88ae4cc0d44858f1dc38696267d93.bindPopup(popup_f75fb5cbf2550f11c1d0aad1bc798de2)
#         ;
#
#
#
#
#             var marker_53111b46b30c87fd5491a18a0e7328a6 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_fa94a5692a2f33567ddece6b781fb3ad);
#
#
#             var icon_6c0c3e49eeea44a453574e57dc76e523 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_53111b46b30c87fd5491a18a0e7328a6.setIcon(icon_6c0c3e49eeea44a453574e57dc76e523);
#
#
#         var popup_51a1a81beccc721248e06f5951c14408 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf2d9ee0446a423b827c48c52a30fdd = $(`&lt;div id=&quot;html_3cf2d9ee0446a423b827c48c52a30fdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_51a1a81beccc721248e06f5951c14408.setContent(html_3cf2d9ee0446a423b827c48c52a30fdd);
#
#
#
#         marker_53111b46b30c87fd5491a18a0e7328a6.bindPopup(popup_51a1a81beccc721248e06f5951c14408)
#         ;
#
#
#
#
#             var marker_8f3da2adda5445457ec7f817157f7f6e = L.marker(
#                 [6.138559, 80.1008014],

# %%
# Step 5: Visualize accurate road-following path
def get_directions_geometry(points):
    route_coords = []
    for i in range(0, len(points) - 1, 20):
        segment = points[i:i+20]
        origin = segment[0]
        destination = segment[-1]
        waypoints = "|".join([f"via:{lat},{lng}" for lat, lng in segment[1:-1]])
        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&waypoints={waypoints}&key={API_KEY}"
        )
        r = requests.get(url).json()
        if r["status"] == "OK":
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
        else:
            print("Polyline error:", r.get("status"), r.get("error_message"))
        time.sleep(0.1)
    return route_coords

route_coords = get_directions_geometry(snapped_path)

# %%
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a92dfc699cab8088b01969ca61d80756 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a92dfc699cab8088b01969ca61d80756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a92dfc699cab8088b01969ca61d80756 = L.map(
#                 &quot;map_a92dfc699cab8088b01969ca61d80756&quot;,
#                 {
#                     center: [6.353311013698626, 80.02614034246584],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a59017afe228b2adb9687be3d0044b16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a59017afe228b2adb9687be3d0044b16.addTo(map_a92dfc699cab8088b01969ca61d80756);
#
#
#             var marker_c9b4bcf945834956556bf8174c08fa1e = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo(map_a92dfc699cab8088b01969ca61d80756);
#
#
#             var icon_9848a86f77bfb172cff539ef5b3f3bcf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c9b4bcf945834956556bf8174c08fa1e.setIcon(icon_9848a86f77bfb172cff539ef5b3f3bcf);
#
#
#         var popup_62caa6e9e285788f8b497816d9c6e6d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38071735f6eabd6546b2cab9bebee70a = $(`&lt;div id=&quot;html_38071735f6eabd6546b2cab9bebee70a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.1008&lt;/div&gt;`)[0];
#                 popup_62caa6e9e285788f8b497816d9c6e6d3.setContent(html_38071735f6eabd6546b2cab9bebee70a);
#
#
#
#         marker_c9b4bcf945834956556bf8174c08fa1e.bindPopup(popup_62caa6e9e285788f8b497816d9c6e6d3)
#         ;
#
#
#
#
#             var marker_60629c3add9d236c50392d66fdb618d3 = L.marker(
#                 [6.13856, 80.1008],
#                 {
# }
#             ).addTo(map_a92dfc699cab8088b01969ca61d80756);
#
#
#             var icon_397988e524e62f2b37d6247bdc0d3536 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_60629c3add9d236c50392d66fdb618d3.setIcon(icon_397988e524e62f2b37d6247bdc0d3536);
#
#
#         var popup_cf4956e41f27c49ae57e44cfb3dd1ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dbea9564c29813fec06b4e423163e1c = $(`&lt;div id=&quot;html_5dbea9564c29813fec06b4e423163e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13856&lt;br&gt;Longitude: 80.1008&lt;/div&gt;`)[0];
#                 popup_cf4956e41f27c49ae57e44cfb3dd1ee5.setContent(html_5dbea9564c29813fec06b4e423163e1c);
#
#
#
#         marker_60629c3add9d236c50392d66fdb618d3.bindPopup(popup_cf4956e41f27c49ae57e44cfb3dd1ee5)
#         ;
#
#
#
#
#             var marker_38ba7aec6b17429dc1873cad3386c40a = L.marker(
#                 [6.13841, 80.10143],
#                 {
# }
#             ).addTo(map_a92dfc699cab8088b01969ca61d80756);
#
#
#             var icon_d45cfe49313d2e3e843eb0cef53a0aaa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_38ba7aec6b17429dc1873cad3386c40a.setIcon(icon_d45cfe49313d2e3e843eb0cef53a0aaa);
#
#
#         var popup_3d73a74857e413e0eb8515f9c8dcd70b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d880c55bcd0af8b304803396719be85b = $(`&lt;div id=&quot;html_d880c55bcd0af8b304803396719be85b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13841&lt;br&gt;Longitude: 80.10143&lt;/div&gt;`)[0];
#                 popup_3d73a74857e413e0eb8515f9c8dcd70b.setContent(html_d880c55bcd0af8b304803396719be85b);
#
#
#
#         marker_38ba7aec6b17429dc1873cad3386c40a.bindPopup(popup_3d73a74857e413e0eb8515f9c8dcd70b)
#         ;
#
#
#
#
#             var marker_bb4f861da213de6a89769e336de7a94f = L.marker(
#                 [6.13837, 80.10149],
#                 {
# }
#             ).ad
