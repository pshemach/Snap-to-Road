# %%
import pandas as pd
import requests
import folium
import polyline
import time
from geopy.distance import geodesic

# %%
# ======= CONFIGURATION =======
API_KEY = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM' # Replace with your actual API key
# FILE_PATH = 'data/Gps-Collection.csv'  # Path to your Excel file
FILE_PATH = 'data/Workbook.csv'  # Path to your Excel file
ACCURACY_THRESHOLD = 50 # Max acceptable GPS accuracy (in meters)
MIN_MOVE_DISTANCE_M = 15  # Minimum movement to keep consecutive point
MAX_SNAP_DISTANCE_M = 5  # Max snap-to-road distance allowed

# %%
# Step 1: Load and filter by GPS accuracy
df = pd.read_csv(FILE_PATH)
df.columns = df.columns.str.strip()
# Convert timestamps
df['DateTime'] = pd.to_datetime(df['DateTime'], format='%d/%m/%Y %I:%M:%S %p')
df_filtered = df[df['Accuracy'] <= ACCURACY_THRESHOLD]
df_filtered = df_filtered[df_filtered['Provider'] == 'gps']  # Optional: Use GPS provider only
df_filtered = df_filtered.sort_values('TimeStamp')

# %%
raw_points = list(zip(df_filtered['Latitude'], df_filtered['Longitude']))
print(f"Loaded {len(raw_points)} raw points (accuracy ≤ {ACCURACY_THRESHOLD})")
# Out:
# Loaded 99147 raw points (accuracy ≤ 50)

# %%
df.columns
# Out:
# Index(['Id', 'Longitude', 'Latitude', 'Accuracy', 'TimeStamp', 'Date',
#        'DateTime', 'IsGPSOn', 'BatLevel', 'Provider', 'Bearing', 'DeviceTime',
#        'RepId'],
#       dtype='object')

# %%
DISTANCE_THRESHOLD_METERS = 50  # Minimum distance to retain a point
# === STEP 2: REMOVE CONCENTRATED POINTS ===
cleaned_points = []
last_point = None

for _, row in df_filtered.iterrows():
    current_point = (row['Latitude'], row['Longitude'])
    if last_point is None:
        cleaned_points.append(row)
        last_point = current_point
    else:
        distance = geodesic(last_point, current_point).meters
        if distance >= DISTANCE_THRESHOLD_METERS:
            cleaned_points.append(row)
            last_point = current_point

# === STEP 3: SAVE CLEANED DATA ===
cleaned_df = pd.DataFrame(cleaned_points)
cleaned_df.shape
# Out:
# (299, 13)

# %%
raw_points = list(zip(cleaned_df['Latitude'], cleaned_df['Longitude']))
print(f"Loaded {len(raw_points)} raw points (accuracy ≤ {ACCURACY_THRESHOLD})")
# Out:
# Loaded 299 raw points (accuracy ≤ 50)

# %%
def visualize_all_locations(df):
    """
    Visualize all locations from a CSV file on a folium map.
    :param csv_file_path: Path to the CSV file containing location data
    :return: folium.Map object
    """
    # Load the CSV data into a DataFrame
    # try:
    #     df = df
    # except Exception as e:
    #     print(f"Error loading CSV file {csv_file_path}: {e}")
    #     return None
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            # popup=f"CODE: {row['CODE']}<br>LOCATION: {row['LOCATION']}<br>ADDRESS: {row['ADDRESS']}<br>BRAND: {row['BRAND']}",
            popup=f"Accuracy: {row['Accuracy']}<br>Latitude: {row['Latitude']}<br>Longitude: {row['Longitude']}<br>DeviceTime: {row['DeviceTime']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">All Locations Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

# %%
visualize_all_locations(cleaned_df)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b1071b435d4ab0cac304363c633a1f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;All Locations Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b1071b435d4ab0cac304363c633a1f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b1071b435d4ab0cac304363c633a1f0 = L.map(
#                 &quot;map_0b1071b435d4ab0cac304363c633a1f0&quot;,
#                 {
#                     center: [6.876898628762541, 80.03061448160534],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b59fad61c16e2a6d00f8079704f2aa91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b59fad61c16e2a6d00f8079704f2aa91.addTo(map_0b1071b435d4ab0cac304363c633a1f0);
#
#
#             var marker_9417b29e3a0250145d85f37e0273d991 = L.marker(
#                 [6.89274, 80.03597],
#                 {
# }
#             ).addTo(map_0b1071b435d4ab0cac304363c633a1f0);
#
#
#             var icon_cb2c41e952137cd7fd30228c7573c9cd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9417b29e3a0250145d85f37e0273d991.setIcon(icon_cb2c41e952137cd7fd30228c7573c9cd);
#
#
#         var popup_52a4c4f796cc40747125d5a7f9ad8c7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b51d14c77ca8386e0c711b95ef0ab80b = $(`&lt;div id=&quot;html_b51d14c77ca8386e0c711b95ef0ab80b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 1.6&lt;br&gt;Latitude: 6.89274&lt;br&gt;Longitude: 80.03597&lt;br&gt;DeviceTime: 15/05/2025 9:29:06 AM&lt;/div&gt;`)[0];
#                 popup_52a4c4f796cc40747125d5a7f9ad8c7e.setContent(html_b51d14c77ca8386e0c711b95ef0ab80b);
#
#
#
#         marker_9417b29e3a0250145d85f37e0273d991.bindPopup(popup_52a4c4f796cc40747125d5a7f9ad8c7e)
#         ;
#
#
#
#
#             var marker_f6f3fee174a497a2d231541ce5773f22 = L.marker(
#                 [6.89329, 80.03596],
#                 {
# }
#             ).addTo(map_0b1071b435d4ab0cac304363c633a1f0);
#
#
#             var icon_2cbfbb83d1591775748d8fa9fa166a2e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f6f3fee174a497a2d231541ce5773f22.setIcon(icon_2cbfbb83d1591775748d8fa9fa166a2e);
#
#
#         var popup_7702f06bcfaf2ec193a277a596e7e7a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97e58bfe72d0439a12b6dc0327a1d1f2 = $(`&lt;div id=&quot;html_97e58bfe72d0439a12b6dc0327a1d1f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 2.4&lt;br&gt;Latitude: 6.89329&lt;br&gt;Longitude: 80.03596&lt;br&gt;DeviceTime: 15/05/2025 9:33:37 AM&lt;/div&gt;`)[0];
#                 popup_7702f06bcfaf2ec193a277a596e7e7a3.setContent(html_97e58bfe72d0439a12b6dc0327a1d1f2);
#
#
#
#         marker_f6f3fee174a497a2d231541ce5773f22.bindPopup(popup_7702f06bcfaf2ec193a277a596e7e7a3)
#         ;
#
#
#
#
#             var marker_3bcdc8e161d1c33dd3649c515e98331b = L.marker(
#                 [6.89331, 80.03645],
#                 {
# }
#             ).addTo(map_0b1071b435d4ab0cac304363c633a1f0);
#
#
#             var icon_37f15ab4199fdce73c230aeb23063dbe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3bcdc8e161d1c33dd3649c515e98331b.setIcon(icon_37f15ab4199fdce73c230aeb23063dbe);
#
#
#         var popup_79d4b198ccfefda747a17cfa9d073783 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c71be1e89aa9451e0ceafbf5b4648d68 = $(`&lt;div id=&quot;html_c71be1e89aa9451e0ceafbf5b4648d68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 1.9&lt;br&gt;Latitude: 6.89331&lt;br&gt;Longitude: 80.03645&lt;br&gt;DeviceTime: 15/05/2025 9:33:51 AM&lt;/div&gt;`)[0];
#                 popup_79d4b198ccfefda747a17cfa9d073783.setContent(html_c71be1e89aa9451e0ceafbf5b4648d68);
#
#
#
#         marker_3bcdc8e161d1c33dd3649c515e98331b.bindPopup(popup_79d4

# %%
# Step 3: Snap to nearest road, reject if too far from road
def snap_to_nearest_road_filtered(points, max_snap_distance_m=15):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=false&key={API_KEY}"
        r = requests.get(url)
        data = r.json()

        if 'snappedPoints' in data:
            for p in data['snappedPoints']:
                if 'originalIndex' not in p:
                    continue
                idx = p['originalIndex']
                original = batch[idx]
                snapped_point = (p['location']['latitude'], p['location']['longitude'])

                distance = geodesic(original, snapped_point).meters
                if distance <= max_snap_distance_m:
                    snapped.append(snapped_point)
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

# %%
snapped_path =snap_to_nearest_road_filtered(raw_points)

# %%
"""View snapped path on map"""
def visualize_snapped_path(snapped_path):
    """
    Visualize the snapped path on a folium map.
    :param snapped_path: List of snapped points
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [sum(p[0] for p in snapped_path) / len(snapped_path),
                      sum(p[1] for p in snapped_path) / len(snapped_path)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each snapped point
    for point in snapped_path:
        folium.Marker(
            location=point,
            popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Snapped Path Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_snapped_path(snapped_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ef7ae088603795c13a6d46d6cb704d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ef7ae088603795c13a6d46d6cb704d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ef7ae088603795c13a6d46d6cb704d5 = L.map(
#                 &quot;map_3ef7ae088603795c13a6d46d6cb704d5&quot;,
#                 {
#                     center: [6.876180273412893, 80.03032122856783],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a080a0b8e0b726c7829b8d9fd451860 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a080a0b8e0b726c7829b8d9fd451860.addTo(map_3ef7ae088603795c13a6d46d6cb704d5);
#
#
#             var marker_75f6ec53dc1d903f4786c91d6a16df9d = L.marker(
#                 [6.893288143603597, 80.03598340079726],
#                 {
# }
#             ).addTo(map_3ef7ae088603795c13a6d46d6cb704d5);
#
#
#             var icon_e3e934312604e04eb176159a6e188f23 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_75f6ec53dc1d903f4786c91d6a16df9d.setIcon(icon_e3e934312604e04eb176159a6e188f23);
#
#
#         var popup_f7c95dad22659bbf17e265b42f97205e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a82c307bb6317a636d9cbad99095000 = $(`&lt;div id=&quot;html_9a82c307bb6317a636d9cbad99095000&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893288143603597&lt;br&gt;Longitude: 80.03598340079726&lt;/div&gt;`)[0];
#                 popup_f7c95dad22659bbf17e265b42f97205e.setContent(html_9a82c307bb6317a636d9cbad99095000);
#
#
#
#         marker_75f6ec53dc1d903f4786c91d6a16df9d.bindPopup(popup_f7c95dad22659bbf17e265b42f97205e)
#         ;
#
#
#
#
#             var marker_9a05d156cf47bdecab570d0ad87ffe73 = L.marker(
#                 [6.8932720681973985, 80.03643640955518],
#                 {
# }
#             ).addTo(map_3ef7ae088603795c13a6d46d6cb704d5);
#
#
#             var icon_6af1c7a020428011adeaa64ef139552c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9a05d156cf47bdecab570d0ad87ffe73.setIcon(icon_6af1c7a020428011adeaa64ef139552c);
#
#
#         var popup_4cd55bec3bfb2bb22e0c7cc8253e91dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f83a798a8d1fa86c5d9dcc2be989cc2 = $(`&lt;div id=&quot;html_0f83a798a8d1fa86c5d9dcc2be989cc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.8932720681973985&lt;br&gt;Longitude: 80.03643640955518&lt;/div&gt;`)[0];
#                 popup_4cd55bec3bfb2bb22e0c7cc8253e91dd.setContent(html_0f83a798a8d1fa86c5d9dcc2be989cc2);
#
#
#
#         marker_9a05d156cf47bdecab570d0ad87ffe73.bindPopup(popup_4cd55bec3bfb2bb22e0c7cc8253e91dd)
#         ;
#
#
#
#
#             var marker_038b9402cc36acf03cf5627d28ac49c1 = L.marker(
#                 [6.893108658594706, 80.03689504312655],
#                 {
# }
#             ).addTo(map_3ef7ae088603795c13a6d46d6cb704d5);
#
#
#             var icon_8db1e6e316aaa3023a294f52adfdeee1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_038b9402cc36acf03cf5627d28ac49c1.setIcon(icon_8db1e6e316aaa3023a294f52adfdeee1);
#
#
#         var popup_2fdd510d4e481ee42345a674560709b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4657c649311f36eb93d72f7292d3995 = $(`&lt;div id=&quot;html_c4657c649311f36eb93d72f7292d3995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.893108658594706&lt;br&gt;Longitude: 80.03689504312655&lt;/div&gt;`)[0];
#                 popup_2fdd510d4e481ee42345a674560709b4.setContent(html_c4657c649311f36eb93d72f7292d3995);
#
#
#
#         marker_038b9402cc36acf03cf5627d28ac49c1.bindPopup(popup_2fdd510d4e481ee42345a674560709b4)
#         ;
#
#
#
#
#             var mark

# %%
def calculate_road_distance(snapped_points):
    total_distance = 0.0

    for i in range(len(snapped_points) - 1):
        origin = f"{snapped_points[i][0]},{snapped_points[i][1]}"
        destination = f"{snapped_points[i+1][0]},{snapped_points[i+1][1]}"
        url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&key={API_KEY}"

        response = requests.get(url).json()
        if response['status'] == 'OK':
            legs = response['routes'][0]['legs']
            for leg in legs:
                total_distance += leg['distance']['value']  # meters
        else:
            print("Error getting directions:", response.get("status"), response.get("error_message"))
        time.sleep(0.1)  # avoid rate limiting

    return total_distance  # in meters

road_distance_m = calculate_road_distance(snapped_path)

# %%
road_distance_m
# Out:
# 16154.0

# %%
# # Step 5A: Get total road distance and path (point-by-point)
# def get_precise_road_path(points):
#     total_km = 0
#     route_coords = []

#     for i in range(len(points) - 1):
#         origin = points[i]
#         destination = points[i + 1]

#         url = (
#             f"https://maps.googleapis.com/maps/api/directions/json?"
#             f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
#             f"&key={API_KEY}"
#         )

#         r = requests.get(url).json()
#         if r["status"] == "OK":
#             poly = r["routes"][0]["overview_polyline"]["points"]
#             route_coords.extend(polyline.decode(poly))
#             for leg in r["routes"][0]["legs"]:
#                 total_km += leg["distance"]["value"] / 1000  # meters to km
#         else:
#             print(f"❗ Segment error [{i}]:", r.get("status"), r.get("error_message"))
#         time.sleep(0.1)

#     return total_km, route_coords
# total_km, route_coords = get_precise_road_path(snapped_path)

from geopy.distance import geodesic

def get_precise_road_path(points, max_segment_m=2000):
    total_km = 0
    route_coords = []

    for i in range(len(points) - 1):
        origin = points[i]
        destination = points[i + 1]
        distance_m = geodesic(origin, destination).meters

        # if distance_m > max_segment_m:
        #     print(f"⚠️ Skipping segment {i} (too far: {distance_m:.1f}m)")
        #     continue

        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&key={API_KEY}"
        )

        r = requests.get(url).json()
        if r.get("status") == "OK":
            try:
                poly = r["routes"][0]["overview_polyline"]["points"]
                route_coords.extend(polyline.decode(poly))
                for leg in r["routes"][0]["legs"]:
                    total_km += leg["distance"]["value"] / 1000
            except Exception as e:
                print(f"⚠️ Polyline decode error at segment {i}: {e}")
        else:
            print(f"❌ Directions error [{i}]:", r.get("status"), r.get("error_message"))

        time.sleep(0.1)

    return total_km, route_coords

# %%
from geopy.distance import geodesic

def filter_dense_points(points, min_distance_m=10):
    filtered = [points[0]]
    for pt in points[1:]:
        if geodesic(filtered[-1], pt).meters >= min_distance_m:
            filtered.append(pt)
    return filtered

# %%
def get_road_distance(points, min_distance_m=20):
    points = filter_dense_points(points, min_distance_m)
    total_km = 0
    route_coords = []

    for i in range(0, len(points) - 1, 9):
        segment = points[i:i+10]
        if len(segment) < 2:
            continue

        origin = segment[0]
        destination = segment[-1]
        waypoints = "|".join([f"via:{lat},{lng}" for lat, lng in segment[1:-1]])

        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&waypoints={waypoints}&key={API_KEY}"
        )

        r = requests.get(url).json()
        if r["status"] == "OK":
            for leg in r["routes"][0]["legs"]:
                total_km += leg["distance"]["value"] / 1000
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
        else:
            print("Directions error:", r.get("status"), r.get("error_message"))
            # Fallback to straight line
            total_km += geodesic(origin, destination).km
        time.sleep(0.1)
    
    return total_km, route_coords

# %%
from geopy.distance import geodesic
import requests
import polyline
import time

def get_hybrid_road_path(points, max_direct_distance_m=50):
    total_km = 0
    route_coords = []

    for i in range(len(points) - 1):
        origin = points[i]
        destination = points[i + 1]
        distance_m = geodesic(origin, destination).meters

        if distance_m <= max_direct_distance_m:
            total_km += distance_m / 1000
            if not route_coords or route_coords[-1] != origin:
                route_coords.append(origin)
            route_coords.append(destination)
        else:
            # 🌐 Use Google Directions API for road-based path
            url = (
                f"https://maps.googleapis.com/maps/api/directions/json?"
                f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
                f"&key={API_KEY}"
            )

            r = requests.get(url).json()
            if r.get("status") == "OK":
                try:
                    poly = r["routes"][0]["overview_polyline"]["points"]
                    route_coords.extend(polyline.decode(poly))
                    for leg in r["routes"][0]["legs"]:
                        total_km += leg["distance"]["value"] / 1000
                except Exception as e:
                    print(f"⚠️ Polyline decode error at segment {i}: {e}")
            else:
                print(f"❌ Directions error [{i}]:", r.get("status"), r.get("error_message"))
                # fallback to geodesic
                total_km += distance_m / 1000
                route_coords.append(origin)
                route_coords.append(destination)

            time.sleep(0.1)  # API rate limit safety

    return total_km, route_coords

# %%
total_km, route_coords = get_precise_road_path(snapped_path)
total_km
# Out:
# 72.779

# %%
total_km, route_coords = get_road_distance(snapped_path)
total_km
# Out:
# 80.695

# %%
total_km, route_coords = get_hybrid_road_path(snapped_path)
total_km
# Out:
# 72.8505654090216

# %%
"""Visualize route_coords on map"""
def visualize_route_coords(route_coords):
    """
    Visualize the route coordinates on a folium map.
    :param route_coords: List of route coordinates
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes 
        map_center = [sum(p[0] for p in route_coords) / len(route_coords),
                      sum(p[1] for p in route_coords) / len(route_coords)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each route coordinate
    for point in route_coords:
            folium.Marker(
                location=point,
                popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
                icon=folium.Icon(color='red', icon='info-sign')
            ).add_to(m)
            
    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Route Coordinates Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8211b716c85e343c44bba20583ecd3aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8211b716c85e343c44bba20583ecd3aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8211b716c85e343c44bba20583ecd3aa = L.map(
#                 &quot;map_8211b716c85e343c44bba20583ecd3aa&quot;,
#                 {
#                     center: [6.4267964019322585, 80.00128322803742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_754e17052c7d9d60dd052079baf2a845 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_754e17052c7d9d60dd052079baf2a845.addTo(map_8211b716c85e343c44bba20583ecd3aa);
#
#
#             var marker_c9b229a3a9a8d2e3010e65c705f8868c = L.marker(
#                 [6.13845, 80.10062],
#                 {
# }
#             ).addTo(map_8211b716c85e343c44bba20583ecd3aa);
#
#
#             var icon_80e762a511c1ede60ffca290a1d3e4c7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c9b229a3a9a8d2e3010e65c705f8868c.setIcon(icon_80e762a511c1ede60ffca290a1d3e4c7);
#
#
#         var popup_94af48fbe9603b08e4e1fdbbb70ea936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c32617cdb29df31380754123699494c5 = $(`&lt;div id=&quot;html_c32617cdb29df31380754123699494c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13845&lt;br&gt;Longitude: 80.10062&lt;/div&gt;`)[0];
#                 popup_94af48fbe9603b08e4e1fdbbb70ea936.setContent(html_c32617cdb29df31380754123699494c5);
#
#
#
#         marker_c9b229a3a9a8d2e3010e65c705f8868c.bindPopup(popup_94af48fbe9603b08e4e1fdbbb70ea936)
#         ;
#
#
#
#
#             var marker_4afee60533565b4fefc5f1dd5edc22c5 = L.marker(
#                 [6.13866, 80.10058],
#                 {
# }
#             ).addTo(map_8211b716c85e343c44bba20583ecd3aa);
#
#
#             var icon_de6ab61f0e82a219d719fea9dec1ac3a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4afee60533565b4fefc5f1dd5edc22c5.setIcon(icon_de6ab61f0e82a219d719fea9dec1ac3a);
#
#
#         var popup_f4273b493b3462388bc5972fed8144ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c1377be413667677329288dc4b0e970 = $(`&lt;div id=&quot;html_8c1377be413667677329288dc4b0e970&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13866&lt;br&gt;Longitude: 80.10058&lt;/div&gt;`)[0];
#                 popup_f4273b493b3462388bc5972fed8144ab.setContent(html_8c1377be413667677329288dc4b0e970);
#
#
#
#         marker_4afee60533565b4fefc5f1dd5edc22c5.bindPopup(popup_f4273b493b3462388bc5972fed8144ab)
#         ;
#
#
#
#
#             var marker_a71f98717bab8f4d80f999a8b0e87905 = L.marker(
#                 [6.13898, 80.10057],
#                 {
# }
#             ).addTo(map_8211b716c85e343c44bba20583ecd3aa);
#
#
#             var icon_ed74e1ddf52af54d3039bfcaa46c99ee = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a71f98717bab8f4d80f999a8b0e87905.setIcon(icon_ed74e1ddf52af54d3039bfcaa46c99ee);
#
#
#         var popup_3a8af095ffbe61735416f8131fdc94ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1375057057f4cec2ac70f94fa58e76ed = $(`&lt;div id=&quot;html_1375057057f4cec2ac70f94fa58e76ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13898&lt;br&gt;Longitude: 80.10057&lt;/div&gt;`)[0];
#                 popup_3a8af095ffbe61735416f8131fdc94ba.setContent(html_1375057057f4cec2ac70f94fa58e76ed);
#
#
#
#         marker_a71f98717bab8f4d80f999a8b0e87905.bindPopup(popup_3a8af095ffbe61735416f8131fdc94ba)
#         ;
#
#
#
#
#             var marker_7591dffac13594a195f1fcd91c66282d = L.marker(
#                 [6.138977027938739, 80.10056991965922],

# %%
def snap_to_roads_full_path(points):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=true&key={API_KEY}"
        r = requests.get(url)
        data = r.json()
        if 'snappedPoints' in data:
            snapped.extend([
                (p['location']['latitude'], p['location']['longitude'])
                for p in data['snappedPoints']
            ])
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

snapped_path =snap_to_roads_full_path(raw_points)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 19
#      16         time.sleep(0.1)
#      17     return snapped
# ---> 19 snapped_path =snap_to_roads_full_path(raw_points)
#
# Cell In[31], line 7, in snap_to_roads_full_path(points)
#       5 path = "|".join([f"{lat},{lng}" for lat, lng in batch])
#       6 url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=true&key={API_KEY}"
# ----> 7 r = requests.get(url)
#       8 data = r.json()
#       9 if 'snappedPoints' in data:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     738     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     739     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742         sock=sock,
#     743         cert_reqs=self.cert_reqs,
#     744         ssl_version=self.ssl_version,
#     745         ssl_minimum_version=self.ssl_minimum_version,
#     746         ssl_maximum_version=self.ssl_maximum_version,
#     747         ca_certs=self.ca_certs,
#     748         ca_cert_dir=self.ca_cert_dir,
#     749         ca_cert_data=self.ca_cert_data,
#     750         cert_file=self.cert_file,
#     751         key_file=self.key_file,
#     752         key_password=self.key_password,
#     753         server_hostname=server_hostname_rm_dot,
#     754         ssl_context=self.ssl_context,
#     755         tls_in_tls=tls_in_tls,
#     756         assert_hostname=self.assert_hostname,
#     757         assert_fingerprint=self.assert_fingerprint,
#     758     )
#     759     self.sock = sock_and_verified.socket
#     761 # If an error occurs during connection/handshake we may need to release
#     762 # our lock so another connection can probe the origin.
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:920, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     917     if is_ipaddress(normalized):
#     918         server_hostname = normalized
# --> 920 ssl_sock = ssl_wrap_socket(
#     921     sock=sock,
#     922     keyfile=key_file,
#     923     certfile=cert_file,
#     924     key_password=key_password,
#     925     ca_certs=ca_certs,
#     926     ca_cert_dir=ca_cert_dir,
#     927     ca_cert_data=ca_cert_data,
#     928     server_hostname=server_hostname,
#     929     ssl_context=context,
#     930     tls_in_tls=tls_in_tls,
#     931 )
#     933 try:
#     934     if assert_fingerprint:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:460, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456         context.load_cert_chain(certfile, keyfile, key_password)
#     458 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 460 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461 return ssl_sock
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\ssl_.py:504, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     501     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     502     return SSLTransport(sock, ssl_context, server_hostname)
# --> 504 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
visualize_snapped_path(snapped_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8da8cd457556eacd2155f474e20ecca3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8da8cd457556eacd2155f474e20ecca3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8da8cd457556eacd2155f474e20ecca3 = L.map(
#                 &quot;map_8da8cd457556eacd2155f474e20ecca3&quot;,
#                 {
#                     center: [6.309807858922011, 80.04271752272876],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b73ebf45b5920b953b391835ca75bbe8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b73ebf45b5920b953b391835ca75bbe8.addTo(map_8da8cd457556eacd2155f474e20ecca3);
#
#
#             var marker_3c7afd9521a707fc9b20af01f6f6553a = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_8da8cd457556eacd2155f474e20ecca3);
#
#
#             var icon_848dd1cc64220a218989df5c6f9a4adb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3c7afd9521a707fc9b20af01f6f6553a.setIcon(icon_848dd1cc64220a218989df5c6f9a4adb);
#
#
#         var popup_c0ca1ebf65bc282ce0b5414d9e4d1040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03f2f20c501e22c2baf14f99d29f2bda = $(`&lt;div id=&quot;html_03f2f20c501e22c2baf14f99d29f2bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_c0ca1ebf65bc282ce0b5414d9e4d1040.setContent(html_03f2f20c501e22c2baf14f99d29f2bda);
#
#
#
#         marker_3c7afd9521a707fc9b20af01f6f6553a.bindPopup(popup_c0ca1ebf65bc282ce0b5414d9e4d1040)
#         ;
#
#
#
#
#             var marker_d857e14e9edc599d4744427b853cfe50 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_8da8cd457556eacd2155f474e20ecca3);
#
#
#             var icon_69248bf1ab7111438f64d37d0fdbcf86 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d857e14e9edc599d4744427b853cfe50.setIcon(icon_69248bf1ab7111438f64d37d0fdbcf86);
#
#
#         var popup_aadb72b0e461e3cab034e95ca8cfb03d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d0f8c98992266a29f6e0bc081a212e6 = $(`&lt;div id=&quot;html_9d0f8c98992266a29f6e0bc081a212e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_aadb72b0e461e3cab034e95ca8cfb03d.setContent(html_9d0f8c98992266a29f6e0bc081a212e6);
#
#
#
#         marker_d857e14e9edc599d4744427b853cfe50.bindPopup(popup_aadb72b0e461e3cab034e95ca8cfb03d)
#         ;
#
#
#
#
#             var marker_0cb32b7dec5c6798f73f69481c4873d9 = L.marker(
#                 [6.138559, 80.1008014],
#                 {
# }
#             ).addTo(map_8da8cd457556eacd2155f474e20ecca3);
#
#
#             var icon_8cb245fef356402c9229f21c84c4c999 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0cb32b7dec5c6798f73f69481c4873d9.setIcon(icon_8cb245fef356402c9229f21c84c4c999);
#
#
#         var popup_9555e46d44955947dda7deea9314e729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e242cde63dd6eb1378c1048e38c671c2 = $(`&lt;div id=&quot;html_e242cde63dd6eb1378c1048e38c671c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.138559&lt;br&gt;Longitude: 80.1008014&lt;/div&gt;`)[0];
#                 popup_9555e46d44955947dda7deea9314e729.setContent(html_e242cde63dd6eb1378c1048e38c671c2);
#
#
#
#         marker_0cb32b7dec5c6798f73f69481c4873d9.bindPopup(popup_9555e46d44955947dda7deea9314e729)
#         ;
#
#
#
#
#             var marker_a2d572e7e1f0b23b8a2e9d1f9cdf67d4 = L.marker(
#                 [6.138559, 80.1008014],

# %%
# Step 5: Visualize accurate road-following path
def get_directions_geometry(points):
    route_coords = []
    for i in range(0, len(points) - 1, 20):
        segment = points[i:i+20]
        origin = segment[0]
        destination = segment[-1]
        waypoints = "|".join([f"via:{lat},{lng}" for lat, lng in segment[1:-1]])
        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&waypoints={waypoints}&key={API_KEY}"
        )
        r = requests.get(url).json()
        if r["status"] == "OK":
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
        else:
            print("Polyline error:", r.get("status"), r.get("error_message"))
        time.sleep(0.1)
    return route_coords

route_coords = get_directions_geometry(snapped_path)

# %%
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0cee835f5d45f4046ef7b60957fe6d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0cee835f5d45f4046ef7b60957fe6d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0cee835f5d45f4046ef7b60957fe6d0 = L.map(
#                 &quot;map_d0cee835f5d45f4046ef7b60957fe6d0&quot;,
#                 {
#                     center: [6.880284191919193, 80.03183830808081],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dc1bf9e65afd13bbef028dd248aa854 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8dc1bf9e65afd13bbef028dd248aa854.addTo(map_d0cee835f5d45f4046ef7b60957fe6d0);
#
#
#             var marker_715c90e0a41a58a808088d37334b40a7 = L.marker(
#                 [6.89319, 80.03598],
#                 {
# }
#             ).addTo(map_d0cee835f5d45f4046ef7b60957fe6d0);
#
#
#             var icon_7fea0ae765ef364249f4b3fe07f5df17 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_715c90e0a41a58a808088d37334b40a7.setIcon(icon_7fea0ae765ef364249f4b3fe07f5df17);
#
#
#         var popup_2429f7dc8de8fe74cf35dca6af01a82d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f60745b3f545fc844c69eb1312657a0c = $(`&lt;div id=&quot;html_f60745b3f545fc844c69eb1312657a0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.89319&lt;br&gt;Longitude: 80.03598&lt;/div&gt;`)[0];
#                 popup_2429f7dc8de8fe74cf35dca6af01a82d.setContent(html_f60745b3f545fc844c69eb1312657a0c);
#
#
#
#         marker_715c90e0a41a58a808088d37334b40a7.bindPopup(popup_2429f7dc8de8fe74cf35dca6af01a82d)
#         ;
#
#
#
#
#             var marker_5829354308b3aabd7c7398d086718eb2 = L.marker(
#                 [6.89342, 80.036],
#                 {
# }
#             ).addTo(map_d0cee835f5d45f4046ef7b60957fe6d0);
#
#
#             var icon_fdcb8dbece82d1b9d9612fb99bcd8f1c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5829354308b3aabd7c7398d086718eb2.setIcon(icon_fdcb8dbece82d1b9d9612fb99bcd8f1c);
#
#
#         var popup_704d566e60a509e350b7b4ede1b31cb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80fddbf69124f8091487a0649d44db82 = $(`&lt;div id=&quot;html_80fddbf69124f8091487a0649d44db82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.89342&lt;br&gt;Longitude: 80.036&lt;/div&gt;`)[0];
#                 popup_704d566e60a509e350b7b4ede1b31cb2.setContent(html_80fddbf69124f8091487a0649d44db82);
#
#
#
#         marker_5829354308b3aabd7c7398d086718eb2.bindPopup(popup_704d566e60a509e350b7b4ede1b31cb2)
#         ;
#
#
#
#
#             var marker_40b36923949bf1e4fd04a02fe1d9f9ac = L.marker(
#                 [6.89338, 80.03612],
#                 {
# }
#             ).addTo(map_d0cee835f5d45f4046ef7b60957fe6d0);
#
#
#             var icon_5cc3d6c88f2f548a41a0dbddc6fb1cc4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_40b36923949bf1e4fd04a02fe1d9f9ac.setIcon(icon_5cc3d6c88f2f548a41a0dbddc6fb1cc4);
#
#
#         var popup_47aa12708640495d3bafcf0e9a54aac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_849e21fd05f869409202e589a8d3e88c = $(`&lt;div id=&quot;html_849e21fd05f869409202e589a8d3e88c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.89338&lt;br&gt;Longitude: 80.03612&lt;/div&gt;`)[0];
#                 popup_47aa12708640495d3bafcf0e9a54aac2.setContent(html_849e21fd05f869409202e589a8d3e88c);
#
#
#
#         marker_40b36923949bf1e4fd04a02fe1d9f9ac.bindPopup(popup_47aa12708640495d3bafcf0e9a54aac2)
#         ;
#
#
#
#
#             var marker_aaa565e1ce9cb8bee2da7a2bb4fc4453 = L.marker(
#                 [6.8932, 80.03664],
#                 {
# }
#             ).add
