# %%
import pandas as pd
import requests
import folium
import polyline
import time
from geopy.distance import geodesic

# %%
# ======= CONFIGURATION =======
API_KEY = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM' # Replace with your actual API key
FILE_PATH = '../data/Gps-Collection.csv'  # Path to your Excel file
ACCURACY_THRESHOLD = 25 # Max acceptable GPS accuracy (in meters)
MIN_MOVE_DISTANCE_M = 15  # Minimum movement to keep consecutive point
MAX_SNAP_DISTANCE_M = 5  # Max snap-to-road distance allowed

# %%
# Step 1: Load and filter by GPS accuracy
df = pd.read_csv(FILE_PATH)
df.columns = df.columns.str.strip()
df_filtered = df[df['Accuracy'] <= ACCURACY_THRESHOLD]
raw_points = list(zip(df_filtered['Latitude'], df_filtered['Longitude']))
print(f"Loaded {len(raw_points)} raw points (accuracy ≤ {ACCURACY_THRESHOLD})")
# Out:
# Loaded 164 raw points (accuracy ≤ 25)

# %%
df.columns
# Out:
# Index(['Id', 'Longitude', 'Latitude', 'Accuracy', 'TimeStamp', 'Date',
#        'DateTime', 'IsGPSOn', 'BatLevel', 'Provider', 'Bearing', 'DeviceTime',
#        'RepId', 'RepName'],
#       dtype='object')

# %%
pd.to_datetime(df['DeviceTime'], errors='coerce')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20264\3851294901.py:1: UserWarning: Parsing dates in %d/%m/%Y %I:%M:%S %p format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(df['DeviceTime'], errors='coerce')
# 0     2025-04-30 07:18:01
# 1     2025-04-30 07:18:04
# 2     2025-04-30 07:18:06
# 3     2025-04-30 07:18:08
# 4     2025-04-30 07:18:10
#               ...
# 223   2025-04-30 09:32:08
# 224   2025-04-30 09:33:28
# 225   2025-04-30 09:34:36
# 226   2025-04-30 09:35:15
# 227   2025-04-30 09:35:22
# Name: DeviceTime, Length: 228, dtype: datetime64[ns]

# %%
def visualize_all_locations(df):
    """
    Visualize all locations from a CSV file on a folium map.
    :param csv_file_path: Path to the CSV file containing location data
    :return: folium.Map object
    """
    # Load the CSV data into a DataFrame
    # try:
    #     df = df
    # except Exception as e:
    #     print(f"Error loading CSV file {csv_file_path}: {e}")
    #     return None
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            # popup=f"CODE: {row['CODE']}<br>LOCATION: {row['LOCATION']}<br>ADDRESS: {row['ADDRESS']}<br>BRAND: {row['BRAND']}",
            popup=f"Accuracy: {row['Accuracy']}<br>Latitude: {row['Latitude']}<br>Longitude: {row['Longitude']}<br>DeviceTime: {row['DeviceTime']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">All Locations Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

# %%
visualize_all_locations(df_filtered)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_015e22d96e330e2ca4f5a0a619a2ef7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;All Locations Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_015e22d96e330e2ca4f5a0a619a2ef7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_015e22d96e330e2ca4f5a0a619a2ef7f = L.map(
#                 &quot;map_015e22d96e330e2ca4f5a0a619a2ef7f&quot;,
#                 {
#                     center: [6.432492926829268, 80.0011324390244],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a526a89f0dddfa7446c87755b20983b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a526a89f0dddfa7446c87755b20983b2.addTo(map_015e22d96e330e2ca4f5a0a619a2ef7f);
#
#
#             var marker_ac1f40b83c18bf6cb81fef42440c3ce5 = L.marker(
#                 [6.13859, 80.10071],
#                 {
# }
#             ).addTo(map_015e22d96e330e2ca4f5a0a619a2ef7f);
#
#
#             var icon_7860a59435ac997c80d61c9b3c972f1f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_ac1f40b83c18bf6cb81fef42440c3ce5.setIcon(icon_7860a59435ac997c80d61c9b3c972f1f);
#
#
#         var popup_ec78f84b63fedd765b49a4a86133d3d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e0bb0252e7c0add031bb11fa440d5cd = $(`&lt;div id=&quot;html_8e0bb0252e7c0add031bb11fa440d5cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 3.5&lt;br&gt;Latitude: 6.13859&lt;br&gt;Longitude: 80.10071&lt;br&gt;DeviceTime: 30/04/2025 7:18:01 AM&lt;/div&gt;`)[0];
#                 popup_ec78f84b63fedd765b49a4a86133d3d2.setContent(html_8e0bb0252e7c0add031bb11fa440d5cd);
#
#
#
#         marker_ac1f40b83c18bf6cb81fef42440c3ce5.bindPopup(popup_ec78f84b63fedd765b49a4a86133d3d2)
#         ;
#
#
#
#
#             var marker_10fa103c2f8f1d7247b2db969ff00470 = L.marker(
#                 [6.13871, 80.10068],
#                 {
# }
#             ).addTo(map_015e22d96e330e2ca4f5a0a619a2ef7f);
#
#
#             var icon_87c96e2340d56ab5e442e0454e299729 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_10fa103c2f8f1d7247b2db969ff00470.setIcon(icon_87c96e2340d56ab5e442e0454e299729);
#
#
#         var popup_0abfbc7fd149134a24a4157fcbecbf7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4952d41e2b3402cf0e601bede202a983 = $(`&lt;div id=&quot;html_4952d41e2b3402cf0e601bede202a983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 3.5&lt;br&gt;Latitude: 6.13871&lt;br&gt;Longitude: 80.10068&lt;br&gt;DeviceTime: 30/04/2025 7:18:04 AM&lt;/div&gt;`)[0];
#                 popup_0abfbc7fd149134a24a4157fcbecbf7e.setContent(html_4952d41e2b3402cf0e601bede202a983);
#
#
#
#         marker_10fa103c2f8f1d7247b2db969ff00470.bindPopup(popup_0abfbc7fd149134a24a4157fcbecbf7e)
#         ;
#
#
#
#
#             var marker_8a7c4b55a75a2cca45d46ff026e952ed = L.marker(
#                 [6.13884, 80.10068],
#                 {
# }
#             ).addTo(map_015e22d96e330e2ca4f5a0a619a2ef7f);
#
#
#             var icon_527248e91af0d7c2eebd8df4c7fea412 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8a7c4b55a75a2cca45d46ff026e952ed.setIcon(icon_527248e91af0d7c2eebd8df4c7fea412);
#
#
#         var popup_41ac670043485eb0484ade612b8d61ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5ad29db4cf51013ac059599528e96b6 = $(`&lt;div id=&quot;html_c5ad29db4cf51013ac059599528e96b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accuracy: 3.0&lt;br&gt;Latitude: 6.13884&lt;br&gt;Longitude: 80.10068&lt;br&gt;DeviceTime: 30/04/2025 7:18:06 AM&lt;/div&gt;`)[0];
#                 popup_41ac670043485eb0484ade612b8d61ba.setContent(html_c5ad29db4cf51013ac059599528e96b6);
#
#
#
#         marker_8a7c4b55a75a2cca45d46ff026e952ed.bindPopup(popup_41ac6

# %%
# Step 3: Snap to nearest road, reject if too far from road
def snap_to_nearest_road_filtered(points, max_snap_distance_m=15):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=false&key={API_KEY}"
        r = requests.get(url)
        data = r.json()

        if 'snappedPoints' in data:
            for p in data['snappedPoints']:
                if 'originalIndex' not in p:
                    continue
                idx = p['originalIndex']
                original = batch[idx]
                snapped_point = (p['location']['latitude'], p['location']['longitude'])

                distance = geodesic(original, snapped_point).meters
                if distance <= max_snap_distance_m:
                    snapped.append(snapped_point)
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

# %%
snapped_path =snap_to_nearest_road_filtered(raw_points)

# %%
"""View snapped path on map"""
def visualize_snapped_path(snapped_path):
    """
    Visualize the snapped path on a folium map.
    :param snapped_path: List of snapped points
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes
        map_center = [sum(p[0] for p in snapped_path) / len(snapped_path),
                      sum(p[1] for p in snapped_path) / len(snapped_path)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each snapped point
    for point in snapped_path:
        folium.Marker(
            location=point,
            popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Snapped Path Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_snapped_path(snapped_path[:-20])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_318a49f54f276b70397bb47d46f8e56d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_318a49f54f276b70397bb47d46f8e56d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_318a49f54f276b70397bb47d46f8e56d = L.map(
#                 &quot;map_318a49f54f276b70397bb47d46f8e56d&quot;,
#                 {
#                     center: [6.140744487532217, 80.0996410772431],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c702ec54849e3b620475a51146d9e46a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c702ec54849e3b620475a51146d9e46a.addTo(map_318a49f54f276b70397bb47d46f8e56d);
#
#
#             var marker_548193e6b418576da49f92196320a5e2 = L.marker(
#                 [6.139873800984828, 80.09971544832543],
#                 {
# }
#             ).addTo(map_318a49f54f276b70397bb47d46f8e56d);
#
#
#             var icon_df8eb9c2c2385bcbc7e59d18a2fbe647 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_548193e6b418576da49f92196320a5e2.setIcon(icon_df8eb9c2c2385bcbc7e59d18a2fbe647);
#
#
#         var popup_1d9c46b15b04af6b1297da75f4ef415a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd6bf644c88d1e7a3759633080fe2063 = $(`&lt;div id=&quot;html_bd6bf644c88d1e7a3759633080fe2063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.139873800984828&lt;br&gt;Longitude: 80.09971544832543&lt;/div&gt;`)[0];
#                 popup_1d9c46b15b04af6b1297da75f4ef415a.setContent(html_bd6bf644c88d1e7a3759633080fe2063);
#
#
#
#         marker_548193e6b418576da49f92196320a5e2.bindPopup(popup_1d9c46b15b04af6b1297da75f4ef415a)
#         ;
#
#
#
#
#             var marker_c46369608d0ed659bd294899eae2a5b2 = L.marker(
#                 [6.139993, 80.09975229999999],
#                 {
# }
#             ).addTo(map_318a49f54f276b70397bb47d46f8e56d);
#
#
#             var icon_76f8fbf959173e0a70f27fb2cc2567ca = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c46369608d0ed659bd294899eae2a5b2.setIcon(icon_76f8fbf959173e0a70f27fb2cc2567ca);
#
#
#         var popup_84c674efbaffeb315fab0933559113ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ad48b26e0e758504a33a16483e98a96 = $(`&lt;div id=&quot;html_4ad48b26e0e758504a33a16483e98a96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.139993&lt;br&gt;Longitude: 80.09975229999999&lt;/div&gt;`)[0];
#                 popup_84c674efbaffeb315fab0933559113ab.setContent(html_4ad48b26e0e758504a33a16483e98a96);
#
#
#
#         marker_c46369608d0ed659bd294899eae2a5b2.bindPopup(popup_84c674efbaffeb315fab0933559113ab)
#         ;
#
#
#
#
#             var marker_1258ce68ad7118469bd6bb307a87fbd0 = L.marker(
#                 [6.140124276788334, 80.09976436656889],
#                 {
# }
#             ).addTo(map_318a49f54f276b70397bb47d46f8e56d);
#
#
#             var icon_51589a23664fa3282ecbf5a6a4f2ce53 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1258ce68ad7118469bd6bb307a87fbd0.setIcon(icon_51589a23664fa3282ecbf5a6a4f2ce53);
#
#
#         var popup_befc39c3bcb106c53097da25c6a9ddad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00e1aa3362b9fd2cb149aa5faeface07 = $(`&lt;div id=&quot;html_00e1aa3362b9fd2cb149aa5faeface07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.140124276788334&lt;br&gt;Longitude: 80.09976436656889&lt;/div&gt;`)[0];
#                 popup_befc39c3bcb106c53097da25c6a9ddad.setContent(html_00e1aa3362b9fd2cb149aa5faeface07);
#
#
#
#         marker_1258ce68ad7118469bd6bb307a87fbd0.bindPopup(popup_befc39c3bcb106c53097da25c6a9ddad)
#         ;
#
#
#
#
#             var marker_e4c81d856c1cc29435

# %%
# Step 5A: Get total road distance and path (point-by-point)
def get_precise_road_path(points):
    total_km = 0
    route_coords = []

    for i in range(len(points) - 1):
        origin = points[i]
        destination = points[i + 1]

        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&key={API_KEY}"
        )

        r = requests.get(url).json()
        if r["status"] == "OK":
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
            for leg in r["routes"][0]["legs"]:
                total_km += leg["distance"]["value"] / 1000  # meters to km
        else:
            print(f"❗ Segment error [{i}]:", r.get("status"), r.get("error_message"))
        time.sleep(0.1)

    return total_km, route_coords
total_km, route_coords = get_precise_road_path(snapped_path[:-20])

# %%
total_km
# Out:
# 0.21099999999999997

# %%
"""Visualize route_coords on map"""
def visualize_route_coords(route_coords):
    """
    Visualize the route coordinates on a folium map.
    :param route_coords: List of route coordinates
    :return: folium.Map object
    """
    try:
        # Create a map centered at the mean of all latitudes and longitudes 
        map_center = [sum(p[0] for p in route_coords) / len(route_coords),
                      sum(p[1] for p in route_coords) / len(route_coords)]
        m = folium.Map(location=map_center, zoom_start=10)
    except Exception as e:
        print(f"Error getting gps data: {e}")
        return None

    # Add a marker for each route coordinate
    for point in route_coords:
            folium.Marker(
                location=point,
                popup=f"Latitude: {point[0]}<br>Longitude: {point[1]}",
                icon=folium.Icon(color='red', icon='info-sign')
            ).add_to(m)
            
    # Add title
    title_html = '<h3 align="center" style="font-size:16px">Route Coordinates Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d032fe563962922893d55c70423048dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d032fe563962922893d55c70423048dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d032fe563962922893d55c70423048dc = L.map(
#                 &quot;map_d032fe563962922893d55c70423048dc&quot;,
#                 {
#                     center: [6.1407384615384615, 80.09964192307692],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b704bd17eff31c19a320b8266bc68747 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b704bd17eff31c19a320b8266bc68747.addTo(map_d032fe563962922893d55c70423048dc);
#
#
#             var marker_25ed4880297193e7a221acff6a7718a3 = L.marker(
#                 [6.13987, 80.09972],
#                 {
# }
#             ).addTo(map_d032fe563962922893d55c70423048dc);
#
#
#             var icon_0660309bb6c6be59967a96edb6f46997 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_25ed4880297193e7a221acff6a7718a3.setIcon(icon_0660309bb6c6be59967a96edb6f46997);
#
#
#         var popup_348e759f26d279428bf2076907039b8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3163aa68d103ea282f3f617e1844ffa = $(`&lt;div id=&quot;html_a3163aa68d103ea282f3f617e1844ffa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13987&lt;br&gt;Longitude: 80.09972&lt;/div&gt;`)[0];
#                 popup_348e759f26d279428bf2076907039b8e.setContent(html_a3163aa68d103ea282f3f617e1844ffa);
#
#
#
#         marker_25ed4880297193e7a221acff6a7718a3.bindPopup(popup_348e759f26d279428bf2076907039b8e)
#         ;
#
#
#
#
#             var marker_4ee700b303ace15635e55e11ddef04f8 = L.marker(
#                 [6.13999, 80.09975],
#                 {
# }
#             ).addTo(map_d032fe563962922893d55c70423048dc);
#
#
#             var icon_63cd33e73df0ac6e2c6d0ab52581f004 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4ee700b303ace15635e55e11ddef04f8.setIcon(icon_63cd33e73df0ac6e2c6d0ab52581f004);
#
#
#         var popup_908d9704d7a696790b750cc46a93ed82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a4f2a9f8aac927dde4a3a6bc4b3756f = $(`&lt;div id=&quot;html_0a4f2a9f8aac927dde4a3a6bc4b3756f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13999&lt;br&gt;Longitude: 80.09975&lt;/div&gt;`)[0];
#                 popup_908d9704d7a696790b750cc46a93ed82.setContent(html_0a4f2a9f8aac927dde4a3a6bc4b3756f);
#
#
#
#         marker_4ee700b303ace15635e55e11ddef04f8.bindPopup(popup_908d9704d7a696790b750cc46a93ed82)
#         ;
#
#
#
#
#             var marker_94ee8caf8247f405149a09364fffeadd = L.marker(
#                 [6.13999, 80.09975],
#                 {
# }
#             ).addTo(map_d032fe563962922893d55c70423048dc);
#
#
#             var icon_e944658e4265259e497824f1d68fdd2b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_94ee8caf8247f405149a09364fffeadd.setIcon(icon_e944658e4265259e497824f1d68fdd2b);
#
#
#         var popup_8a6cb174fd5f1b9025f08080c643ce46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ec04cea83b61313cb8b6784d4f0fd9c = $(`&lt;div id=&quot;html_1ec04cea83b61313cb8b6784d4f0fd9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13999&lt;br&gt;Longitude: 80.09975&lt;/div&gt;`)[0];
#                 popup_8a6cb174fd5f1b9025f08080c643ce46.setContent(html_1ec04cea83b61313cb8b6784d4f0fd9c);
#
#
#
#         marker_94ee8caf8247f405149a09364fffeadd.bindPopup(popup_8a6cb174fd5f1b9025f08080c643ce46)
#         ;
#
#
#
#
#             var marker_80f3383a8ff2aa3aafb47563deee51e8 = L.marker(
#                 [6.14012, 80.09976],
#                 {
# }

# %%
def snap_to_roads_full_path(points):
    snapped = []
    for i in range(0, len(points), 100):
        batch = points[i:i+100]
        path = "|".join([f"{lat},{lng}" for lat, lng in batch])
        url = f"https://roads.googleapis.com/v1/snapToRoads?path={path}&interpolate=true&key={API_KEY}"
        r = requests.get(url)
        data = r.json()
        if 'snappedPoints' in data:
            snapped.extend([
                (p['location']['latitude'], p['location']['longitude'])
                for p in data['snappedPoints']
            ])
        else:
            print("Snap error:", data.get("status"), data.get("error_message"))
        time.sleep(0.1)
    return snapped

snapped_path =snap_to_roads_full_path(raw_points)

# %%
visualize_snapped_path(snapped_path)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29ed11db3a097787e0a31c14cee2f290 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Snapped Path Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29ed11db3a097787e0a31c14cee2f290&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29ed11db3a097787e0a31c14cee2f290 = L.map(
#                 &quot;map_29ed11db3a097787e0a31c14cee2f290&quot;,
#                 {
#                     center: [6.452333190082938, 79.99438718782156],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46c0139af1283df8ad3bb8a36a339385 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46c0139af1283df8ad3bb8a36a339385.addTo(map_29ed11db3a097787e0a31c14cee2f290);
#
#
#             var marker_f1d0e4dc17669c9085b6689574bde958 = L.marker(
#                 [6.1387826, 80.10018880000001],
#                 {
# }
#             ).addTo(map_29ed11db3a097787e0a31c14cee2f290);
#
#
#             var icon_6099fb7ecde057775e646bd37ccd556f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_f1d0e4dc17669c9085b6689574bde958.setIcon(icon_6099fb7ecde057775e646bd37ccd556f);
#
#
#         var popup_37dcc9e8818649360cc815c0cb6dbfd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf9d91b94c28d5dd88a0ca254ed8909b = $(`&lt;div id=&quot;html_cf9d91b94c28d5dd88a0ca254ed8909b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.1387826&lt;br&gt;Longitude: 80.10018880000001&lt;/div&gt;`)[0];
#                 popup_37dcc9e8818649360cc815c0cb6dbfd1.setContent(html_cf9d91b94c28d5dd88a0ca254ed8909b);
#
#
#
#         marker_f1d0e4dc17669c9085b6689574bde958.bindPopup(popup_37dcc9e8818649360cc815c0cb6dbfd1)
#         ;
#
#
#
#
#             var marker_00f426a72f22df11413b3f6cd1ce508d = L.marker(
#                 [6.1387826, 80.10018880000001],
#                 {
# }
#             ).addTo(map_29ed11db3a097787e0a31c14cee2f290);
#
#
#             var icon_0f70eb239fdebfb37591c38840eb8a30 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_00f426a72f22df11413b3f6cd1ce508d.setIcon(icon_0f70eb239fdebfb37591c38840eb8a30);
#
#
#         var popup_49a9664c363fa214fe0462fbf2ce84a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10d22b656ce4da4d7c5394edf9ed09ed = $(`&lt;div id=&quot;html_10d22b656ce4da4d7c5394edf9ed09ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.1387826&lt;br&gt;Longitude: 80.10018880000001&lt;/div&gt;`)[0];
#                 popup_49a9664c363fa214fe0462fbf2ce84a3.setContent(html_10d22b656ce4da4d7c5394edf9ed09ed);
#
#
#
#         marker_00f426a72f22df11413b3f6cd1ce508d.bindPopup(popup_49a9664c363fa214fe0462fbf2ce84a3)
#         ;
#
#
#
#
#             var marker_86e2f78c4127e1a8a6160ee78b576629 = L.marker(
#                 [6.1387826, 80.10018880000001],
#                 {
# }
#             ).addTo(map_29ed11db3a097787e0a31c14cee2f290);
#
#
#             var icon_eafcfd9ed2cc2398cd80a23df2707673 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_86e2f78c4127e1a8a6160ee78b576629.setIcon(icon_eafcfd9ed2cc2398cd80a23df2707673);
#
#
#         var popup_b9dfddb6e2aa59cebd51e92f8b0e8903 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc72fcff76adcdcc2301b1b1e1b3c3d = $(`&lt;div id=&quot;html_1bc72fcff76adcdcc2301b1b1e1b3c3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.1387826&lt;br&gt;Longitude: 80.10018880000001&lt;/div&gt;`)[0];
#                 popup_b9dfddb6e2aa59cebd51e92f8b0e8903.setContent(html_1bc72fcff76adcdcc2301b1b1e1b3c3d);
#
#
#
#         marker_86e2f78c4127e1a8a6160ee78b576629.bindPopup(popup_b9dfddb6e2aa59cebd51e92f8b0e8903)
#         ;
#
#
#
#
#             var marker_4bc3f7eb7189212bb0a011a4865a37e4 = L.marker(

# %%
# Step 5: Visualize accurate road-following path
def get_directions_geometry(points):
    route_coords = []
    for i in range(0, len(points) - 1, 20):
        segment = points[i:i+20]
        origin = segment[0]
        destination = segment[-1]
        waypoints = "|".join([f"via:{lat},{lng}" for lat, lng in segment[1:-1]])
        url = (
            f"https://maps.googleapis.com/maps/api/directions/json?"
            f"origin={origin[0]},{origin[1]}&destination={destination[0]},{destination[1]}"
            f"&waypoints={waypoints}&key={API_KEY}"
        )
        r = requests.get(url).json()
        if r["status"] == "OK":
            poly = r["routes"][0]["overview_polyline"]["points"]
            route_coords.extend(polyline.decode(poly))
        else:
            print("Polyline error:", r.get("status"), r.get("error_message"))
        time.sleep(0.1)
    return route_coords

route_coords = get_directions_geometry(snapped_path)

# %%
visualize_route_coords(route_coords)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc9774f6f41091b1b840bc589e6469f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Route Coordinates Map&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc9774f6f41091b1b840bc589e6469f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc9774f6f41091b1b840bc589e6469f2 = L.map(
#                 &quot;map_fc9774f6f41091b1b840bc589e6469f2&quot;,
#                 {
#                     center: [6.450343441558441, 79.99235458874469],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97caa9cea1073eb3d8d850af0ffd31f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97caa9cea1073eb3d8d850af0ffd31f7.addTo(map_fc9774f6f41091b1b840bc589e6469f2);
#
#
#             var marker_4d8e66b5f0e64630b351fccb4e240c51 = L.marker(
#                 [6.13875, 80.1004],
#                 {
# }
#             ).addTo(map_fc9774f6f41091b1b840bc589e6469f2);
#
#
#             var icon_e462725bc94ad4f3e512ea0039a9246a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_4d8e66b5f0e64630b351fccb4e240c51.setIcon(icon_e462725bc94ad4f3e512ea0039a9246a);
#
#
#         var popup_fccb41e9af30fbe8378d47a7d0f3e1f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df26e7a36cbe95d518d3bd7f847dd2de = $(`&lt;div id=&quot;html_df26e7a36cbe95d518d3bd7f847dd2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13875&lt;br&gt;Longitude: 80.1004&lt;/div&gt;`)[0];
#                 popup_fccb41e9af30fbe8378d47a7d0f3e1f1.setContent(html_df26e7a36cbe95d518d3bd7f847dd2de);
#
#
#
#         marker_4d8e66b5f0e64630b351fccb4e240c51.bindPopup(popup_fccb41e9af30fbe8378d47a7d0f3e1f1)
#         ;
#
#
#
#
#             var marker_badd8c2b83e6134f5a14cb0a7c63bc79 = L.marker(
#                 [6.13866, 80.10058],
#                 {
# }
#             ).addTo(map_fc9774f6f41091b1b840bc589e6469f2);
#
#
#             var icon_29ecb4c68e6458dc1cdd54c6677548f4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_badd8c2b83e6134f5a14cb0a7c63bc79.setIcon(icon_29ecb4c68e6458dc1cdd54c6677548f4);
#
#
#         var popup_3c4108b356b072146672e027103b86b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b4f34c9d75765a751864286cf2109d0 = $(`&lt;div id=&quot;html_1b4f34c9d75765a751864286cf2109d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13866&lt;br&gt;Longitude: 80.10058&lt;/div&gt;`)[0];
#                 popup_3c4108b356b072146672e027103b86b3.setContent(html_1b4f34c9d75765a751864286cf2109d0);
#
#
#
#         marker_badd8c2b83e6134f5a14cb0a7c63bc79.bindPopup(popup_3c4108b356b072146672e027103b86b3)
#         ;
#
#
#
#
#             var marker_9417eeaf5458ed4166adf945ce8db790 = L.marker(
#                 [6.13906, 80.10057],
#                 {
# }
#             ).addTo(map_fc9774f6f41091b1b840bc589e6469f2);
#
#
#             var icon_1392a189676dc413a3bd67bf99b818a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9417eeaf5458ed4166adf945ce8db790.setIcon(icon_1392a189676dc413a3bd67bf99b818a3);
#
#
#         var popup_128df167f5f65f79fb9c63bf56748e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_364820706b165b68519efebb63b23f71 = $(`&lt;div id=&quot;html_364820706b165b68519efebb63b23f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: 6.13906&lt;br&gt;Longitude: 80.10057&lt;/div&gt;`)[0];
#                 popup_128df167f5f65f79fb9c63bf56748e3f.setContent(html_364820706b165b68519efebb63b23f71);
#
#
#
#         marker_9417eeaf5458ed4166adf945ce8db790.bindPopup(popup_128df167f5f65f79fb9c63bf56748e3f)
#         ;
#
#
#
#
#             var marker_72e03653ad0dde0dba4621f4f539abd5 = L.marker(
#                 [6.13923, 80.10057],
#                 {
# }
#             ).
